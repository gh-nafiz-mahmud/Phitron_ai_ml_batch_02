# %%
length = int(input("Enter the length of the rectangle: "))
width = int(input("Enter the width of the rectangle: "))

area = length * width
print(f"The area of the rectangle is: {area}")

# %%
# The eval() function

a = eval(input("Enter something: "))
print(a, type(a))

b = input("Enter something: ")
print(b, type(b))

# %%
# Formathing string and number

x = 3.34
# x = format(x, "20.3f")
# x = format(x, ">25.3f")
# x = format(x, ".3%")
# x = eval(format(x, ".2%")) # problemetic eval

# 20 min width and 3 decimal places
# format(1.2, ">7.3f")  # '  1.200'  (right align)
# format(1.2, "^7.3f")  # ' 1.200 '  (center align)
# format(1.2, "<7.3f")  # '1.200  '  (left align)

type(print(format(34.3654, ".2%")))

# print(x)
# print(type(x))

# %%
# Python inbuilt function

import math

print(math.ceil(3.4))
print(math.floor(34.34))
print(math.exp(3))  # math.exp(x) computes eˣ, where e ≈ 2.71828 (Euler’s number)
print(math.log(10))
print(math.log(10, 10))
print(math.sqrt(16))
print(abs(-34.34))
print(abs(34.34))

# %%
# The ord and chr functions
# play with ascii values

print(ord('A')) # 65
print(ord('a')) # 97
print(chr(65)) # 'A'
print(chr(97)) # 'a'

print(round(1.5))
print("{:,}".format(1254216514322)) #1,254,216,514,322
# modern way
print(f"{233245346353:,}")

# "{:,}".format(x)	    add comma separators
# f"{x:,}"	            cleaner modern formatting
