# %%
name = "Nafiz"
fatherName = "Nazrul"
mother_name = "Momtaz"
age = 27102005
weight = 50.5

print(name, fatherName, mother_name, age, weight)

# %%
usr_input = input("Enter name: ")
print(usr_input, type(usr_input))

# %%
a = 5
b = 3

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)

# %%
a = 10
b = 76
c = 49
d = 26
e = 88
f = 14

print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
print(a == b)
print(a != b)

print(a + b - c / d * f // e)
print((a + (b - c)) / (d * e) // f)

# %%
a = "c"
b = "d"

d = 66
e = 66
f = 5

if a == b:
    print(True)
elif a != b:
    if d == e:
        print("d == e")
    print(False)
else:
    if f == 5:
        print("f")
    print("Nothing")

# %%
# print(list(range(0, 11)))

for i in range(0, 11):
    print(i, end=" ")

print()

for i in range(0, 11, 2):
    print(i, end=" ")

# %%
i = 0
while i < 11:
    print(i, end=" ")
    i += 1  # i = i + 1

# %%
for i in range(11):
    if i == 3:
        continue
    elif i == 4:
        break
    print(i)

# %%
string = "Nafiz Mahmud Shawon"
father_name = ["Nafiz", "Mahmud", "Shawon"]

print(string[::-1])
print(string[0:5])

print(string.split())
print(", ".join(father_name))
print(", ".join(string))

# %%
name = "shawon"
age = 21
print(f"My name is {name} age is {age}")

# %%
item = ["nafiz", 2, True, 1]
numm = [2, 3, 5, 6, 7, 8, 9, 1, 2, 33, 4, 566, 777, 88]
# for items in item:
#     print(items)
#     pass

# item.append(False)
# print(item)
# item.clear()
# temp_item = item.copy()
# print(item.count(0))
# item.extend('123')
# print(item.index(True))
# item.insert(0,'first')
# item.pop(2)
# item.remove(2)
# item.reverse()
# numm.sort()
# numm.sort(reverse=True)
# print(numm)
# print(item)
# print(temp_item)

# %%
stack = []
stack.append(1)
stack.append(2)
stack.append(3)
stack.append(4)
stack.append(5)

# List as Stack

print(stack)

print(stack.pop())
print(stack)

print(stack.pop())
print(stack)

print(stack.pop())
print(stack)

print(stack.pop())
print(stack)

print(stack.pop())
print(stack)

# %%
# List as Queue

queue = []
queue.append(1)
queue.append(2)
queue.append(3)
queue.append(4)
queue.append(5)

for i in range(len(queue)):
    print(queue)
    print(queue.pop(0))

# %%
even = []
for i in range(100):
    if i % 2 != 0:
        even.append(i)
# print(even)

# comprehension

list = [i for i in range(100) if i % 2 != 0]
print(list)

# %%
fruits = ["apple", "orange", "banana"]

cap_fr = []
for fruit in fruits:
    cap_fr.append(fruit.upper())
# print(cap_fr)

capitalised = [fruit.upper() for fruit in fruits]
print(capitalised)

# %%
tup = ()
print(type(tup))

tup = (1, 2, 2, 3, 4, 5)
print(tup)
tup.count(6)
tup.index(3)

print(tup[::-1])
print(tup[1:3])

# %%
a = {1, 2, 3}
b = {1, 2, 3, 4, 5}

# print(a.union(b))
# print(a.intersection(b))
# print(a.isdisjoint(b))
# print(a.issubset(b))


# a.add(10)
# a.add(0)
# a.pop()
# a.remove('111')
# print(a)

# print(a)
# print(a[0:1]) # set object is not subscriptable
# print(5 in a)
sum = 0
for i in a:
    sum += i

# print(sum)

# %%
keyvalue = {
    "name": "Nafiz",
    "age": 21,
    # "hobby": "segc",
    "hobby": ["coding", "football", "gaming"],
}

# keyvalue.update({'blood': 'o+'})
print(keyvalue.get("agee", "Not found"))
# print(keyvalue)
# print(keyvalue['hobby'][::-1])

dic2 = keyvalue.copy()
print(dic2)
# print(keyvalue.keys())
# print(keyvalue.values())

# keyvalue.pop('name')
# keyvalue.popitem()
# keyvalue.popitem()

# print(keyvalue)

# %%
# Out:
#   Cell In[2], line 2
#     yield i
#     ^
# SyntaxError: 'yield' outside function
