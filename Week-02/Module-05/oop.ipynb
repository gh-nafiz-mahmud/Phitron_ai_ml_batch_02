# %%
# a = 5
# print(type(a))


class computer:
    def config(self):
        print("i7, 32gb, 1tb")


com = computer()
# print(type(com))

# value = computer.config(com)
com.config()

# print(value)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'conda_env (Python 3.12.13)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
