# %% [markdown]
# Registered mail: work.nafiz@gmail.com

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(24)

# %%
num_employees = 50

# %%
# Employee data
emp_ids = np.arange(101, 101 + num_employees)
emp_ages = np.random.randint(20, 55, num_employees)
emp_income = np.random.randint(35000, 95000, num_employees)

# %%
# Fixed set of roles (repetition allowed)
roles_list = [
    "HR Manager",
    "Software Developer",
    "Accountant",
    "Marketing Executive",
    "Sales Executive",
    "Backend Developer",
    "HR Executive",
    "Financial Analyst",
    "Digital Marketer",
    "Operations Manager"
]

emp_roles = np.random.choice(roles_list, num_employees)

# %%
# Create DataFrame
data = pd.DataFrame({
    "emp_id": emp_ids,
    "emp_age": emp_ages,
    "emp_salary": emp_income,
    "role": emp_roles
})

# %%
data.to_csv("staff_data.csv", index=False)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
emp_age = np.array(emp_ages)
emp_salary = np.array(emp_income)

print(emp_age, emp_age.dtype, emp_age.ndim, emp_age.shape, len(emp_age), sep='\n')

print(emp_salary, emp_salary.dtype, emp_salary.ndim, emp_salary.shape, len(emp_salary), sep='\n')
# Out:
# [54 23 20 43 37 37 21 35 24 38 31 35 29 38 27 45 51 48 20 32 51 53 21 26
#  53 37 26 21 45 30 20 47 53 53 23 24 21 30 27 25 39 20 47 41 22 52 42 54
#  31 50]
# int64
# 1
# (50,)
# 50
# [51725 38495 35452 82295 72187 58915 76159 92864 76155 90494 68641 48079
#  56879 83682 94722 91041 48899 68744 63187 74146 75641 47678 76760 78354
#  60584 79898 59682 71888 51086 73700 82550 71447 76100 72269 73314 87428
#  94427 84188 52013 63326 44396 59500 55523 58602 90794 41061 82331 73048
#  59727 50398]
# int64
# 1
# (50,)
# 50

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# amx and min salary
print(f"max salary: {np.max(emp_salary)}, min salary: {np.min(emp_salary)}")

# average salary
print(f"average salary: {np.average(emp_salary)}")

# avg age
print(f"average age: {np.average(emp_age)}")
# Out:
# max salary: 94722, min salary: 35452
# average salary: 68409.48
# average age: 35.44

# %% [markdown]
# ![Screenshot 2026-04-25 095446.png](data:image/png;base64,...)

# %%
arr_age = np.array(emp_ages)
arr_salary = np.array(emp_income)

# filtered age
age = np.extract(np.logical_and(arr_age >= 25, arr_age <= 40), arr_age)
print(age)
print(f"employee satisty this condition in ages is : {len(age)}\n")

# filtered salary
salary = np.extract(np.logical_and(arr_salary > 50000, arr_salary), arr_salary)
print(salary)
print(f"employee satisty this condition in salary is : {len(salary)}\n\n")
# Out:
# [37 37 35 38 31 35 29 38 27 32 26 37 26 30 30 27 25 39 31]
# employee satisty this condition in ages is : 19
#
# [51725 82295 72187 58915 76159 92864 76155 90494 68641 56879 83682 94722
#  91041 68744 63187 74146 75641 76760 78354 60584 79898 59682 71888 51086
#  73700 82550 71447 76100 72269 73314 87428 94427 84188 52013 63326 59500
#  55523 58602 90794 82331 73048 59727 50398]
# employee satisty this condition in salary is : 43

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
emp_age = np.array(emp_ages)
avg = np.average(emp_ages)

new_arr = np.array(np.where(emp_age < avg, emp_age + 4, emp_age + 2))

# original aray
print(emp_age)

# duplicate array
print(new_arr)

# average aged used for condition
print(f"average age used for condition : {avg}")
# Out:
# [54 23 20 43 37 37 21 35 24 38 31 35 29 38 27 45 51 48 20 32 51 53 21 26
#  53 37 26 21 45 30 20 47 53 53 23 24 21 30 27 25 39 20 47 41 22 52 42 54
#  31 50]
# [56 27 24 45 39 39 25 39 28 40 35 39 33 40 31 47 53 50 24 36 53 55 25 30
#  55 39 30 25 47 34 24 49 55 55 27 28 25 34 31 29 41 24 49 43 26 54 44 56
#  35 52]
# average age used for condition : 35.44

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
emp_role = np.array(emp_roles)

so1 = np.extract(emp_role == 'Digital Marketer', emp_salary)
so2 = np.extract(emp_role == 'Backend Developer', emp_salary)
so3 = np.extract(emp_role == 'Software Developer', emp_salary)


dm_bd_sd_total = sum(so1) + sum(so2) + sum(so3)
dm_bd_sd_8_increased_total = (dm_bd_sd_total * (8/100)) + dm_bd_sd_total
without_8_total = sum(emp_salary)
total_salary_expense = (without_8_total + (dm_bd_sd_8_increased_total - dm_bd_sd_total))

print(f"new total salary expense is {total_salary_expense}")
print(f"overall increase in expense is {total_salary_expense - without_8_total:.2f}\n")

print(f"new total: {total_salary_expense}")
print(f"old total: {without_8_total}")
print(f"new - old differences : {total_salary_expense - without_8_total:.2f}")
# Out:
# new total salary expense is 3524808.08
# overall increase in expense is 104334.08
#
# new total: 3524808.08
# old total: 3420474
# new - old differences : 104334.08

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = pd.read_csv('staff_data.csv')

print(df[:3])
print(df.info())
print(df.describe())
# Out:
#    emp_id  emp_age  emp_salary                role
# 0     101       54       51725          HR Manager
# 1     102       23       38495          Accountant
# 2     103       20       35452  Operations Manager
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      50 non-null     int64
#  1   emp_age     50 non-null     int64
#  2   emp_salary  50 non-null     int64
#  3   role        50 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 1.7+ KB
# None
#           emp_id    emp_age    emp_salary
# count   50.00000  50.000000     50.000000
# mean   125.50000  35.440000  68409.480000
# std     14.57738  11.768446  15727.122334
# min    101.00000  20.000000  35452.000000
# 25%    113.25000  24.250000  57309.750000
# 50%    125.50000  35.000000  72037.500000
# 75%    137.75000  46.500000  79512.000000
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
filtered_df = df.filter(items=['emp_id', 'emp_age', 'role'])

age_condition = filtered_df.loc[(filtered_df['emp_age'] >= 25) & (filtered_df['emp_age'] <= 40)]

emp_id_sort = age_condition.sort_values('emp_id')
print(emp_id_sort.tail(3))
# Out:
#     emp_id  emp_age                 role
# 39     140       25      Sales Executive
# 40     141       39  Marketing Executive
# 48     149       31     Digital Marketer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
filtered_df = df.copy()
hr_filter = filtered_df.loc[(filtered_df['role']=='HR Manager') | (filtered_df['role']=='HR Executive')]
print(hr_filter)

count = 0
for i in hr_filter['role']:
  count += 1
print(f"total number of HR employees is {count}")
# Out:
#     emp_id  emp_age  emp_salary          role
# 0      101       54       51725    HR Manager
# 5      106       37       58915    HR Manager
# 9      110       38       90494  HR Executive
# 24     125       53       60584  HR Executive
# 27     128       21       71888  HR Executive
# 38     139       27       52013    HR Manager
# 42     143       47       55523  HR Executive
# 44     145       22       90794  HR Executive
# 45     146       52       41061    HR Manager
# total number of HR employees is 9

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
copy_df = df.copy()

emp_age_sorting_asceding_df = copy_df.sort_values('emp_age')
emp_salary_sorting_descending =emp_age_sorting_asceding_df.sort_values('emp_salary', ascending=False)

final_filter = emp_salary_sorting_descending.filter(['emp_id', 'role', 'emp_salary'])
print(final_filter.head(5))
# Out:
#     emp_id               role  emp_salary
# 14     115   Digital Marketer       94722
# 36     137    Sales Executive       94427
# 7      108    Sales Executive       92864
# 15     116  Financial Analyst       91041
# 44     145       HR Executive       90794

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Unable to solved this question
